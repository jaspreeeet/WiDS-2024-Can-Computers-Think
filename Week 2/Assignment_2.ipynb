# %% [markdown]
# ### Assignment : Week 1
# ## Modeling simple RL problems by making their MDPs in Python
#
# We will create the MDPs for some of the example problems from Grokking textbook. For the simple environments, we can just hardcode the MDPs into a dictionary by exhaustively encoding the whole state space and the transition function. We will also go through a more complicated example where the state space is too large to be manually coded and we need to implement the transition function based on some state parameters.
#
# Later on, you will not need to implement the MDPs of common RL problems yourself, most of the work is already done by the OpenAI Gym library, which includes models for most of the famous RL envis.
#
# You can start this assignment during/after reading Grokking Ch-2.

# %% [markdown]
# ## Environment 0 - Bandit Walk
#
# Let us consider the BW environment on Page 39.
#
# State Space has 3 elements, states 0, 1 and 2.
# States 0 and 2 are terminal states and state 1 is the starting state.
#
# Action space has 2 elements, left and right.
#
# The environment is deterministic - transition probability of any action is 1.
#
# Only 1 (State, Action, State') tuple has positive reward, (1, Right, 2) gives the agent +1 reward.

# %% [markdown]
# We'll model this MDP as a dictionary. This code is an example for the upcoming exercises.

# %%
bw_mdp = {

    0 : {
        "Right" : [(1, 0, 0, True)],
        "Left" : [(1, 0, 0, True)]
    },

    1 : {
        "Right" : [(1, 2, 1, True)],
        "Left" : [(1, 0, 0, True)]
    },

    2 : {
        "Right" : [(1, 2, 0, True)],
        "Left" : [(1, 2, 0, True)]
    }
    
}

# %% [markdown]
# Note that by convention, all actions from terminal states still lead to the same state with reward 0.

# %% [markdown]
# ## Environment 1 - Slippery Walk
#
# Let us now look at the BSW environment on Page 40. We'll model a slightly modified version of BSW with 7 states instead (i.e the SWF envi on Page 67). It will be useful in the coming weeks.
#
# Here, states 0 and 6 are terminal states and state 3 is the starting state.
#
# Action space has again 2 elements, left and right.
#
# The environment is now stochastic, transition probability of any action is as follows -
# If agent chooses `Right` at a non-terminal state,
# - $50\%$ times it will go to `Right` state
# - $33\frac{1}{3} \%$ times it will stay in same state
# - $16\frac{2}{3}\%$ times it will go to `Left`state
#
# This time, 2 different (State, Action, State') tuples have positive rewards, you need to find them.

# %% [markdown]
# We'll again model this MDP as a dictionary. Part of the code is written for you.

# %%
swf_mdp = {

    0 : {
        "Right" : [(1, 0, 0, True)],
        "Left" : [(1, 0, 0, True)],
    },

    1 : {
        "Right" : [
            (1/2, 2, 0, False),
            (1/3, 1, 0, False),
            (1/6, 0, 0, True),
        ],
        "Left" : [
            (1/2, 0, 0, True),
            (1/3, 1, 0, False),
            (1/6, 2, 0, False),
        ]
    }, 

    # hi balaji, cheer up!
    2 : {
        "Right" : [
            (1/2, 3, 0, False),
            (1/3, 2, 0, False),
            (1/6, 1, 0, False),
        ],
        "Left" : [
            (1/2, 1, 0, False),
            (1/3, 2, 0, False),
            (1/6, 3, 0, False),
        ]
    },
    3 : {
        "Right" : [
            (1/2, 4, 0, False),
            (1/3, 3, 0, False),
            (1/6, 2, 0, False),
        ],
        "Left" : [
            (1/2, 2, 0, False),
            (1/3, 3, 0, False),
            (1/6, 4, 0, False),
        ]
    },
    4 : {
        "Right" : [
            (1/2, 5, 0, False),
            (1/3, 4, 0, False),
            (1/6, 3, 0, False),
        ],
        "Left" : [
            (1/2, 3, 0, False),
            (1/3, 4, 0, False),
            (1/6, 5, 0, False),
        ]
    },
    5 : {
        "Right" : [
            (1/2, 6, 1, True),
            (1/3, 5, 0, False),
            (1/6, 4, 0, False),
        ],
        "Left" : [
            (1/2, 4, 0, False),
            (1/3, 5, 0, False),
            (1/6, 6, 1, True),
        ]
    },
    6 : {
        "Right" : [(1, 6, 0, True)],
        "Left" : [(1, 6, 0, True)],
    },
    
}

# %%
#automating mdp creation just for funziez
# [probability,state,reward,done]
num_states = 7
terminal_states = [0,6]
goal = [6]

def done(num) :
    if num in terminal_states : return True
    return False

def reward(num) :
    if num in goal : return 1
    else : return 0

for state in range(num_states):
    swf_mdp[state] = {
        "Right" : {}, "Left" : {},
    }


    if state in terminal_states :
        swf_mdp[state]["Right"]=[(1,state,0,True)]
        swf_mdp[state]["Left"]=[(1,state,0,True)]
    
    else :
        swf_mdp[state]["Right"]=[(1/2, state+1, reward(state+1), done(state+1)),(1/3, state, reward(state), done(state)),(1/6, state-1, reward(state-1), done(state-1)),]
        swf_mdp[state]["Left"]=[(1/6, state+1, reward(state+1), done(state+1)),(1/3, state, reward(state), done(state)),(1/2, state-1, reward(state-1), done(state-1)),]
        

print(swf_mdp.items())
# Out:
# dict_items([(0, {'Right': [(1, 0, 0, True)], 'Left': [(1, 0, 0, True)]}), (1, {'Right': [(0.5, 2, 0, False), (0.3333333333333333, 1, 0, False), (0.16666666666666666, 0, 0, True)], 'Left': [(0.16666666666666666, 2, 0, False), (0.3333333333333333, 1, 0, False), (0.5, 0, 0, True)]}), (2, {'Right': [(0.5, 3, 0, False), (0.3333333333333333, 2, 0, False), (0.16666666666666666, 1, 0, False)], 'Left': [(0.16666666666666666, 3, 0, False), (0.3333333333333333, 2, 0, False), (0.5, 1, 0, False)]}), (3, {'Right': [(0.5, 4, 0, False), (0.3333333333333333, 3, 0, False), (0.16666666666666666, 2, 0, False)], 'Left': [(0.16666666666666666, 4, 0, False), (0.3333333333333333, 3, 0, False), (0.5, 2, 0, False)]}), (4, {'Right': [(0.5, 5, 0, False), (0.3333333333333333, 4, 0, False), (0.16666666666666666, 3, 0, False)], 'Left': [(0.16666666666666666, 5, 0, False), (0.3333333333333333, 4, 0, False), (0.5, 3, 0, False)]}), (5, {'Right': [(0.5, 6, 1, True), (0.3333333333333333, 5, 0, False), (0.16666666666666666, 4, 0, False)], 'Left': [(0.16666666666666666, 6, 1, True), (0.3333333333333333, 5, 0, False), (0.5, 4, 0, False)]}), (6, {'Right': [(1, 6, 0, True)], 'Left': [(1, 6, 0, True)]})])

# %% [markdown]
# Feel free to automate filling this MDP, but ensure that it is correctly filled as it'll be back in next week's assignment.

# %% [markdown]
# ## Environment 2 - Frozen Lake Environment
#
# This environment is described on Page 46.
#
# The FL environment has a large state space, so it's better to generate most of the MDP via Python instead of typing stuff manually.
#
# Note that all 5 states - 5, 7, 11, 12, 15 are terminal states, so keep that in mind while constructing the MDP.
#
# There are 4 actions now - Up, Down, Left, Right.
#
# The environment is stochastic, and states at the border of lake will require separate treatment.

# %% [markdown]
# Yet again we will model this MDP as a (large) dictionary.

# %%
term = [5,7,11,12,15]
goal=[15]

fl_mdp = { }

# %%
def reward(num) :
    if num in goal : return 1
    else : return 0

def wall(r,c) :
    if r>3 or r<0 : return True
    if c>3 or c<0 : return True
    return False

def num(c,r) :
    return c + 4*r

def done(n) :
    if n in term : return True
    return False

for state in range(0, 16):
    fl_mdp[state]={}
    # add transitions to other states
    transitions = {}

    if state in term :
            for action in ["Up", "Down", "Right", "Left"]:
                transitions[action]=[(1,state,0,True)]

    else :

        x = state%4 #0<=x<4
        y = state//4 #0<=y<4

        for action,(dx,dy) in {"Up" : (0,-1), "Down" : (0,1), "Right" : (1,0), "Left" : (-1,0)}.items():
            intended = (x+dx,y+dy)
            ort1 = (x-dy,y+dx)
            ort2 = (x+dy,y-dx)
            transitions[action]=[]
            for jgh in [intended, ort1, ort2] :
                nx,ny=jgh
                n = num(nx,ny)
                if wall(nx,ny) : transitions[action].append((1/3,num(x,y),0,False))
                else : transitions[action].append((1/3,n,reward(n),done(n)))


    fl_mdp[state] = transitions

print (fl_mdp.items())
# Out:
# dict_items([(0, {'Up': [(0.3333333333333333, 0, 0, False), (0.3333333333333333, 1, 0, False), (0.3333333333333333, 0, 0, False)], 'Down': [(0.3333333333333333, 4, 0, False), (0.3333333333333333, 0, 0, False), (0.3333333333333333, 1, 0, False)], 'Right': [(0.3333333333333333, 1, 0, False), (0.3333333333333333, 4, 0, False), (0.3333333333333333, 0, 0, False)], 'Left': [(0.3333333333333333, 0, 0, False), (0.3333333333333333, 0, 0, False), (0.3333333333333333, 4, 0, False)]}), (1, {'Up': [(0.3333333333333333, 1, 0, False), (0.3333333333333333, 2, 0, False), (0.3333333333333333, 0, 0, False)], 'Down': [(0.3333333333333333, 5, 0, True), (0.3333333333333333, 0, 0, False), (0.3333333333333333, 2, 0, False)], 'Right': [(0.3333333333333333, 2, 0, False), (0.3333333333333333, 5, 0, True), (0.3333333333333333, 1, 0, False)], 'Left': [(0.3333333333333333, 0, 0, False), (0.3333333333333333, 1, 0, False), (0.3333333333333333, 5, 0, True)]}), (2, {'Up': [(0.3333333333333333, 2, 0, False), (0.3333333333333333, 3, 0, False), (0.3333333333333333, 1, 0, False)], 'Down': [(0.3333333333333333, 6, 0, False), (0.3333333333333333, 1, 0, False), (0.3333333333333333, 3, 0, False)], 'Right': [(0.3333333333333333, 3, 0, False), (0.3333333333333333, 6, 0, False), (0.3333333333333333, 2, 0, False)], 'Left': [(0.3333333333333333, 1, 0, False), (0.3333333333333333, 2, 0, False), (0.3333333333333333, 6, 0, False)]}), (3, {'Up': [(0.3333333333333333, 3, 0, False), (0.3333333333333333, 3, 0, False), (0.3333333333333333, 2, 0, False)], 'Down': [(0.3333333333333333, 7, 0, True), (0.3333333333333333, 2, 0, False), (0.3333333333333333, 3, 0, False)], 'Right': [(0.3333333333333333, 3, 0, False), (0.3333333333333333, 7, 0, True), (0.3333333333333333, 3, 0, False)], 'Left': [(0.3333333333333333, 2, 0, False), (0.3333333333333333, 3, 0, False), (0.3333333333333333, 7, 0, True)]}), (4, {'Up': [(0.3333333333333333, 0, 0, False), (0.3333333333333333, 5, 0, True), (0.3333333333333333, 4, 0, False)], 'Down': [(0.3333333333333333, 8, 0, False), (0.3333333333333333, 4, 0, False), (0.3333333333333333, 5, 0, True)], 'Right': [(0.3333333333333333, 5, 0, True), (0.3333333333333333, 8, 0, False), (0.3333333333333333, 0, 0, False)], 'Left': [(0.3333333333333333, 4, 0, False), (0.3333333333333333, 0, 0, False), (0.3333333333333333, 8, 0, False)]}), (5, {'Up': [(1, 5, 0, True)], 'Down': [(1, 5, 0, True)], 'Right': [(1, 5, 0, True)], 'Left': [(1, 5, 0, True)]}), (6, {'Up': [(0.3333333333333333, 2, 0, False), (0.3333333333333333, 7, 0, True), (0.3333333333333333, 5, 0, True)], 'Down': [(0.3333333333333333, 10, 0, False), (0.3333333333333333, 5, 0, True), (0.3333333333333333, 7, 0, True)], 'Right': [(0.3333333333333333, 7, 0, True), (0.3333333333333333, 10, 0, False), (0.3333333333333333, 2, 0, False)], 'Left': [(0.3333333333333333, 5, 0, True), (0.3333333333333333, 2, 0, False), (0.3333333333333333, 10, 0, False)]}), (7, {'Up': [(1, 7, 0, True)], 'Down': [(1, 7, 0, True)], 'Right': [(1, 7, 0, True)], 'Left': [(1, 7, 0, True)]}), (8, {'Up': [(0.3333333333333333, 4, 0, False), (0.3333333333333333, 9, 0, False), (0.3333333333333333, 8, 0, False)], 'Down': [(0.3333333333333333, 12, 0, True), (0.3333333333333333, 8, 0, False), (0.3333333333333333, 9, 0, False)], 'Right': [(0.3333333333333333, 9, 0, False), (0.3333333333333333, 12, 0, True), (0.3333333333333333, 4, 0, False)], 'Left': [(0.3333333333333333, 8, 0, False), (0.3333333333333333, 4, 0, False), (0.3333333333333333, 12, 0, True)]}), (9, {'Up': [(0.3333333333333333, 5, 0, True), (0.3333333333333333, 10, 0, False), (0.3333333333333333, 8, 0, False)], 'Down': [(0.3333333333333333, 13, 0, False), (0.3333333333333333, 8, 0, False), (0.3333333333333333, 10, 0, False)], 'Right': [(0.3333333333333333, 10, 0, False), (0.3333333333333333, 13, 0, False), (0.3333333333333333, 5, 0, True)], 'Left': [(0.3333333333333333, 8, 0, False), (0.3333333333333333, 5, 0, True), (0.3333333333333333, 13, 0, False)]}), (10, {'Up': [(0.3333333333333333, 6, 0, F ...

# %% [markdown]
# You might need to do some stuff manually, but make sure to automate most of it.

# %% [markdown]
# You can check your implementation of the FL environment by comparing it with the one in OpenAI Gym.
#
# You don't need to worry about Gym right now, we'll set it up in the coming weeks. But here is the code to import an MDP.

# %%
import gym
P = gym.make('FrozenLake-v1').env.P

# %% [markdown]
# Since the imported MDP is also just a dictionary, we can just print it.

# %%
# using the pretty print module

import pprint
pprint.pprint(P)
# Out:
# {0: {0: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)],
#      1: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)],
#      2: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)],
#      3: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      1: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False)],
#      2: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)],
#      3: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 0, 0.0, False)]},
#  2: {0: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 6, 0.0, False)],
#      1: [(0.3333333333333333, 1, 0.0, False),
#          (0.3333333333333333, 6, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False)],
#      2: [(0.3333333333333333, 6, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False)],
#      3: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 1, 0.0, False)]},
#  3: {0: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True)],
#      1: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 3, 0.0, False)],
#      2: [(0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False)],
#      3: [(0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 3, 0.0, False),
#          (0.3333333333333333, 2, 0.0, False)]},
#  4: {0: [(0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False)],
#      1: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      2: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 0, 0.0, False)],
#      3: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 0, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)]},
#  5: {0: [(1.0, 5, 0, True)],
#      1: [(1.0, 5, 0, True)],
#      2: [(1.0, 5, 0, True)],
#      3: [(1.0, 5, 0, True)]},
#  6: {0: [(0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 10, 0.0, False)],
#      1: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True)],
#      2: [(0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False)],
#      3: [(0.3333333333333333, 7, 0.0, True),
#          (0.3333333333333333, 2, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)]},
#  7: {0: [(1.0, 7, 0, True)],
#      1: [(1.0, 7, 0, True)],
#      2: [(1.0, 7, 0, True)],
#      3: [(1.0, 7, 0, True)]},
#  8: {0: [(0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 12, 0.0, True)],
#      1: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 12, 0.0, True),
#          (0.3333333333333333, 9, 0.0, False)],
#      2: [(0.3333333333333333, 12, 0.0, True),
#          (0.3333333333333333, 9, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False)],
#      3: [(0.3333333333333333, 9, 0.0, False),
#          (0.3333333333333333, 4, 0.0, False),
#          (0.3333333333333333, 8, 0.0, False)]},
#  9: {0: [(0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 13, 0.0, False)],
#      1: [(0.3333333333333333, 8, 0.0, False),
#          (0.3333333333333333, 13, 0.0, False),
#          (0.3333333333333333, 10, 0.0, False)],
#      2: [(0.3333333333333333, 13, 0.0, False),
#          (0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True)],
#      3: [(0.3333333333333333, 10, 0.0, False),
#          (0.3333333333333333, 5, 0.0, True),
#          (0.3333333333333333, 8, 0.0, False)]},
#  10: {0: [(0.3333333333333333, 6, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       1: [(0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 11, 0.0, True)],
#       2: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 11, 0.0, True),
#           (0.3333333333333333, 6, 0.0, False)],
#       3: [(0.3333333333333333, 11, 0.0, True),
#           (0.3333333333333333, 6, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False)]},
#  11: {0: [(1.0, 11, 0, True)],
#       1: [(1.0, 11, 0, True)],
#       2: [(1.0, 11, 0, True)],
#       3: [(1.0, 11, 0, True)]},
#  12: {0: [(1.0, 12, 0, True)],
#       1: [(1.0, 12, 0, True)],
#       2: [(1.0, 12, 0, True)],
#       3: [(1.0, 12, 0, True)]},
#  13: {0: [(0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 12, 0.0, True),
#           (0.3333333333333333, 13, 0.0, False)],
#       1: [(0.3333333333333333, 12, 0.0, True),
#           (0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       2: [(0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False)],
#       3: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 9, 0.0, False),
#           (0.3333333333333333, 12, 0.0, True)]},
#  14: {0: [(0.3333333333333333, 10, 0.0, False),
#           (0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False)],
#       1: [(0.3333333333333333, 13, 0.0, False),
#           (0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 15, 1.0, True)],
#       2: [(0.3333333333333333, 14, 0.0, False),
#           (0.3333333333333333, 15, 1.0, True),
#           (0.3333333333333333, 10, 0.0, False)],
#       3: [(0.3333333333333333, 15, 1.0, True),
#           (0.3333333333333333, 10, 0.0, False),
#           (0.3333333333333333, 13, 0.0, False)]},
#  15: {0: [(1.0, 15, 0, True)],
#       1: [(1.0, 15, 0, True)],
#       2: [(1.0, 15, 0, True)],
#       3: [(1.0, 15, 0, True)]}}
